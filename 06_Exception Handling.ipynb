# %%
a = 12
b = 0 
print(a / b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 a = 12
#       2 b = 0
# ----> 3 print(a / b)
#
# ZeroDivisionError: division by zero

# %%
a = "uday"
print(a / 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 a = "uday"
# ----> 2 print(a / 2)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
a = "UDay"
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 a = "UDay"
# ----> 2 int(a)
#
# ValueError: invalid literal for int() with base 10: 'UDay'

# %%
b = "Uday"
float(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 b = "Uday"
# ----> 2 float(b)
#
# ValueError: could not convert string to float: 'Uday'

# %%
a = 12
b = 0
print(a / b)
print("Hello")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 a = 12
#       2 b = 0
# ----> 3 print(a / b)
#       4 print("Hello")
#
# ZeroDivisionError: division by zero

# %%
def division(a: float, b: float ) -> float:
    return a / b

# %%
r1 = division(3, 4)
print(r1)
print("Division Done!!")
# Out:
# 0.75
# Division Done!!

# %%
r2 = division(12.5, 0)
print(r2)
print("Done")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 r2 = division(12.5, 0)
#       2 print(r2)
#       3 print("Done")
#
# Cell In[6], line 2, in division(a, b)
#       1 def division(a: float, b: float ) -> float:
# ----> 2     return a / b
#
# ZeroDivisionError: division by zero

# %%
r3 = division("Uday", 2)
print(r3)
print("Done")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 r3 = division("Uday", 2)
#       2 print(r3)
#       3 print("Done")
#
# Cell In[6], line 2, in division(a, b)
#       1 def division(a: float, b: float ) -> float:
# ----> 2     return a / b
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
def division2(num: float, den: float) -> float:
    try:
        return num / den
    except Exception as e:
        print(f"Exception Occured: {e}")

# %%
r1 = division2(num=12, den=13)
print(r1)
print("Done")
# Out:
# 0.9230769230769231
# Done

# %%
r2 = division2(num=12, den=0)
print(r2)
print("Done")
# Out:
# Exception Occured: division by zero
# None
# Done

# %%
r3 = division2(num="UDay", den=12)
print(r3)
print("Done")
# Out:
# Exception Occured: unsupported operand type(s) for /: 'str' and 'int'
# None
# Done

# %%
r4 = division2(num=25 , den="Sayali")
print(r4)
print("Done")
# Out:
# Exception Occured: unsupported operand type(s) for /: 'int' and 'str'
# None
# Done

# %%
def division3(num: float, den: float)-> float:
    try:
        return num/den
    except ZeroDivisionError:
        print("Denominator cannot be 0")
    except TypeError:
        print("Cannot divide string and numbers, Enter numbers only")

# %%
r1 = division3(num=12, den="uday")
print(r1)
print("Done")
# Out:
# Cannot divide string and numbers, Enter numbers only
# None
# Done

# %%
r2 = division3(num=12, den=0)
print(r2)
print("Done")
# Out:
# Denominator cannot be 0
# None
# Done

# %%
r3 = division3(num=12, den=4)
print(r3)
print("Done")
# Out:
# 3.0
# Done

# %%
def validate_age(age: int) -> int:
    if not isinstance(age, int):
        raise TypeError("Age should always be an integer")
    if age < 18 or age > 100:
        raise ValueError("Age should be between 18 to 100")
    print(f"Valid age entered: {age}")
    return age

# %%
age1 = validate_age(20)
# Out:
# Valid age entered: 20

# %%
age2 = validate_age(15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 age2 = validate_age(15)
#
# Cell In[26], line 5, in validate_age(age)
#       3     raise TypeError("Age should always be an integer")
#       4 if age < 18 or age > 100:
# ----> 5     raise ValueError("Age should be between 18 to 100")
#       6 print(f"Valid age entered: {age}")
#       7 return age
#
# ValueError: Age should be between 18 to 100

# %%
age3 = validate_age("uday")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 age3 = validate_age("uday")
#
# Cell In[26], line 3, in validate_age(age)
#       1 def validate_age(age: int) -> int:
#       2     if not isinstance(age, int):
# ----> 3         raise TypeError("Age should always be an integer")
#       4     if age < 18 or age > 100:
#       5         raise ValueError("Age should be between 18 to 100")
#
# TypeError: Age should always be an integer

# %%
try:
    age = int(input("Please enter the age:  "))
    validate_age(age)
except Exception as e:
    print(f"Exception Occurred : {e}")
# Out:
# Exception Occurred : Age should be between 18 to 100

# %%
import math
def square_root(num: int|float)-> float:
    try:
        s = math.sqrt(num)
    except Exception as e:
        print(f"Exception occurred : {e}")
    else:
        print(f"Square root of {num} is {s}")
    finally:
        print("Finally block will always be executed")

# %%
square_root(25)
# Out:
# Square root of 25 is 5.0
# Finally block will always be executed

# %%
square_root(30)
# Out:
# Square root of 30 is 5.477225575051661
# Finally block will always be executed

# %%
square_root("UDay")
# Out:
# Exception occurred : must be real number, not str
# Finally block will always be executed

# %%
url = "https://drive.google.com/drive/folders/1gBEI1fbJQGkgCV0Gv_k7zvVKunbuv4Ra"
print(url)
# Out:
# https://drive.google.com/drive/folders/1gBEI1fbJQGkgCV0Gv_k7zvVKunbuv4Ra

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'drive',
#  'folders',
#  '1gBEI1fbJQGkgCV0Gv_k7zvVKunbuv4Ra']

# %%
 url.split("/")[-1]
# Out:
# '1gBEI1fbJQGkgCV0Gv_k7zvVKunbuv4Ra'
